# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # First let's take a look at the dataset

# %%
#loading in the datasets
df_training = pd.read_csv('data/archive/train.csv')
df_testing = pd.read_csv('data/archive/test.csv')

# %%
df_training.shape
# Out:
# (7352, 563)

# %%
df_training.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
df_testing.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.257178          -0.023285          -0.014654         -0.938404
# 1           0.286027          -0.013163          -0.119083         -0.975415
# 2           0.275485          -0.026050          -0.118152         -0.993819
# 3           0.270298          -0.032614          -0.117520         -0.994743
# 4           0.274833          -0.027848          -0.129527         -0.993852
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.920091         -0.667683         -0.952501         -0.925249
# 1         -0.967458         -0.944958         -0.986799         -0.968401
# 2         -0.969926         -0.962748         -0.994403         -0.970735
# 3         -0.973268         -0.967091         -0.995274         -0.974471
# 4         -0.967445         -0.978295         -0.994111         -0.965953
#
# ...

# %%
df_training.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        7352.000000        7352.000000        7352.000000
# mean            0.274488          -0.017695          -0.109141
# std             0.070261           0.040811           0.056635
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262975          -0.024863          -0.120993
# 50%             0.277193          -0.017219          -0.108676
# 75%             0.288461          -0.010783          -0.097794
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       7352.000000       7352.000000       7352.000000       7352.000000
# mean          -0.605438         -0.510938         -0.604754         -0.630512
# std            0.448734          0.502645          0.418687          0.424073
# min           -1.000000         -0.999873         -1.000000         -1.000000
# ...

# %%
df_testing.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count        2947.000000        2947.000000        2947.000000
# mean            0.273996          -0.017863          -0.108386
# std             0.060570           0.025745           0.042747
# min            -0.592004          -0.362884          -0.576184
# 25%             0.262075          -0.024961          -0.121162
# 50%             0.277113          -0.016967          -0.108458
# 75%             0.288097          -0.010143          -0.097123
# max             0.671887           0.246106           0.494114
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count       2947.000000       2947.000000       2947.000000       2947.000000
# mean          -0.613635         -0.508330         -0.633797         -0.641278
# std            0.412597          0.494269          0.362699          0.385199
# min           -0.999606         -1.000000         -0.998955         -0.999417
# ...

# %% [markdown]
# ### We can see that both datasets have variables that are all around the same values, meaning we will not need to normalize the values

# %% [markdown]
# ### Now let's look at our dependent variable, which in our project will be predicting the activity of a user based on the phone's sensors. The column 'Activity' dictates what the person was doing while having the phone attached.
#
# ### Let's look at how many different values of activities we will have, and from this we can also see if the activities are balanced throughout the dataset, as we don't want one activity to be significantly more in the data than the rest since this would lead to a weaker model.

# %%
df_training['Activity'].value_counts()
# Out:
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: Activity, dtype: int64

# %%
df_testing['Activity'].value_counts()
# Out:
# LAYING                537
# STANDING              532
# WALKING               496
# SITTING               491
# WALKING_UPSTAIRS      471
# WALKING_DOWNSTAIRS    420
# Name: Activity, dtype: int64

# %% [markdown]
# ### From here we see that the activity labels are in fact balanced in both the training and test sets, and we will further show this in the EDA portion

# %% [markdown]
# ## Now let's see how many total subjects are in our dataset

# %%
df_training['subject'].value_counts()
# Out:
# 25    409
# 21    408
# 26    392
# 30    383
# 28    382
# 27    376
# 23    372
# 17    368
# 16    366
# 19    360
# 1     347
# 29    344
# 3     341
# 15    328
# 6     325
# 14    323
# 22    321
# 11    316
# 7     308
# 5     302
# 8     281
# Name: subject, dtype: int64

# %%
df_testing['subject'].value_counts()
# Out:
# 24    381
# 18    364
# 20    354
# 13    327
# 12    320
# 4     317
# 2     302
# 10    294
# 9     288
# Name: subject, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
#TSNE is used for creating visuals on high dimensional data
from sklearn.manifold import TSNE

# %%
#only taking the columns that will be independent variables
scatter_x = df_training.iloc[:,:-2]

# %%
scatter_x.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  tBodyAcc-std()-X  \
# 0           0.288585          -0.020294          -0.132905         -0.995279
# 1           0.278419          -0.016411          -0.123520         -0.998245
# 2           0.279653          -0.019467          -0.113462         -0.995380
# 3           0.279174          -0.026201          -0.123283         -0.996091
# 4           0.276629          -0.016570          -0.115362         -0.998139
#
#    tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  tBodyAcc-mad()-Y  \
# 0         -0.983111         -0.913526         -0.995112         -0.983185
# 1         -0.975300         -0.960322         -0.998807         -0.974914
# 2         -0.967187         -0.978944         -0.996520         -0.963668
# 3         -0.983403         -0.990675         -0.997099         -0.982750
# 4         -0.980817         -0.990482         -0.998321         -0.979672
#
# ...

# %%
#Fitting to our training set
tsne = TSNE(perplexity = 50).fit_transform(scatter_x)

# %%
plt.figure(figsize = (15,10))
sns.scatterplot(x = tsne[:,0], y = tsne[:,1], hue = df_training["Activity"], palette = 'dark')
plt.xlabel('TSNE 1')
plt.ylabel('TSNE 2')
plt.show()

# %%
#Making pie chart of all acitivites in training set to see how they are represented
pie, ax = plt.subplots(figsize=[12,8])
labels = ['LAYING', 'STANDING', 'SITTING', 'WALKING', 'WALKING_UPSTAIRS', 'WALKING_DOWNSTAIRS']
plt.pie(x=df_training['Activity'].value_counts().to_list(), autopct="%.1f%%", labels=labels,
        explode = (.05,.05,.05,.05,.05,.05), pctdistance=0.5)
plt.title("Activity Distribution", fontsize=14)
plt.show()

# %%
df_training['Activity'].value_counts()
# Out:
# LAYING                1407
# STANDING              1374
# SITTING               1286
# WALKING               1226
# WALKING_UPSTAIRS      1073
# WALKING_DOWNSTAIRS     986
# Name: Activity, dtype: int64

# %%
#Make a boxplot with one specific feature
df_training.columns.to_list()
# Out:
# ['tBodyAcc-mean()-X',
#  'tBodyAcc-mean()-Y',
#  'tBodyAcc-mean()-Z',
#  'tBodyAcc-std()-X',
#  'tBodyAcc-std()-Y',
#  'tBodyAcc-std()-Z',
#  'tBodyAcc-mad()-X',
#  'tBodyAcc-mad()-Y',
#  'tBodyAcc-mad()-Z',
#  'tBodyAcc-max()-X',
#  'tBodyAcc-max()-Y',
#  'tBodyAcc-max()-Z',
#  'tBodyAcc-min()-X',
#  'tBodyAcc-min()-Y',
#  'tBodyAcc-min()-Z',
#  'tBodyAcc-sma()',
#  'tBodyAcc-energy()-X',
#  'tBodyAcc-energy()-Y',
#  'tBodyAcc-energy()-Z',
#  'tBodyAcc-iqr()-X',
#  'tBodyAcc-iqr()-Y',
#  'tBodyAcc-iqr()-Z',
#  'tBodyAcc-entropy()-X',
#  'tBodyAcc-entropy()-Y',
#  'tBodyAcc-entropy()-Z',
#  'tBodyAcc-arCoeff()-X,1',
#  'tBodyAcc-arCoeff()-X,2',
#  'tBodyAcc-arCoeff()-X,3',
#  'tBodyAcc-arCoeff()-X,4',
#  'tBodyAcc-arCoeff()-Y,1',
#  'tBodyAcc-arCoeff()-Y,2',
#  'tBodyAcc-arCoeff()-Y,3',
#  'tBodyAcc-arCoeff()-Y,4',
#  'tBodyAcc-arCoeff()-Z,1',
#  'tBodyAcc-arCoeff()-Z,2',
#  'tBodyAcc-arCoeff()-Z,3',
#  'tBodyAcc-arCoeff()-Z,4',
#  'tBodyAcc-correlation()-X,Y',
# ...

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x = 'Activity', y = 'tBodyAccJerkMag-mean()', data = df_training, palette = 'colorblind', showfliers = False)
plt.title("Body Acceleration Jerk Mean Across Activities")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x = 'Activity', y = 'tGravityAccMag-mean()', data = df_training, palette = 'colorblind', showfliers = False)
plt.title("Gravity Acceleration Jerk Mean Across Activities")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x = 'Activity', y = 'tBodyAccMag-mean()', data = df_training, palette = 'colorblind', showfliers = False)
plt.title("Body Acceleration Mean Across Activities")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x = 'Activity', y = 'tBodyGyroMag-mean()', data = df_training, palette = 'colorblind', showfliers = False)
plt.title("Body Gyro Mean Across Activities")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x = 'Activity', y = 'angle(X,gravityMean)', data = df_training, palette = 'colorblind', showfliers = False)
plt.title("Angle Gravity Mean Across Activities")
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.boxplot(x = 'Activity', y = 'fBodyAccMag-energy()', data = df_training, palette = 'colorblind', showfliers = False)
plt.title("Angle Gravity Mean Across Activities")
plt.show()

# %%
#Looking at Gyro mean across activities through line plot
plt.figure(figsize = (15,10))
sns.distplot(df_training[df_training['Activity'] == 'SITTING']['tBodyGyroMag-mean()'], hist = False, label = 'Sitting')
sns.distplot(df_training[df_training['Activity'] == 'LAYING']['tBodyGyroMag-mean()'], hist = False, label = 'Laying')
sns.distplot(df_training[df_training['Activity'] == 'STANDING']['tBodyGyroMag-mean()'], hist = False, label = 'Standing')
sns.distplot(df_training[df_training['Activity'] == 'WALKING_UPSTAIRS']['tBodyGyroMag-mean()'], hist = False, label = 'Walking Upstairs')
sns.distplot(df_training[df_training['Activity'] == 'WALKING_DOWNSTAIRS']['tBodyGyroMag-mean()'], hist = False, label = 'Walking Downstairs')
sns.distplot(df_training[df_training['Activity'] == 'WALKING']['tBodyGyroMag-mean()'], hist = False, label = 'Walking')
plt.title('Body Gyro Mean across Activites')
plt.show()

# %%
x = df_training.get("tBodyAcc-mean()-X")
y = df_training.get("tBodyAcc-mean()-Y")
z = df_training.get("tBodyAcc-mean()-Z")
activity = df_training.get("Activity")

# %%
new_df = pd.DataFrame().assign(
    x = x,
    y = y,
    z = z,
    activity = activity
)

# %%
new_df = new_df[new_df['activity'].isin(["STANDING", "SITTING", "LAYING"])]
only_standing = new_df[new_df.get("activity") == "STANDING"]
only_sitting = new_df[new_df.get("activity") == "SITTING"]
only_laying = new_df[new_df.get("activity") == "LAYING"]

# %%
ax = plt.axes(projection='3d')
ax.scatter3D(only_standing.get('x'), only_standing.get('y'), only_standing.get('z'), 
             c = "red", label = "STANDING")

ax.scatter3D(only_sitting.get('x'), only_sitting.get('y'), only_sitting.get('z'), 
             c = "blue", label = "SITTING")

ax.scatter3D(only_laying.get('x'), only_laying.get('y'), only_laying.get('z'), 
             c = "green", label = "LAYING", alpha = 0.5)

ax.legend()
plt.show()

# %% [markdown]
# # PCA - Principal Component Analysis

# %%
#Start my importing the necessary library
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 5)

# %%
#Now we have to extract only the independent variables 
x_train_pca = df_training.iloc[:,:-2]
x_test_pca = df_testing.iloc[:,:-2]

# %%
#Now let's fit our features to our pca model on both training and test sets
train_components = pca.fit_transform(x_train_pca)
test_components = pca.fit_transform(x_test_pca)

# %%
#Let's look at our pca features for training set 
pca_train_df = pd.DataFrame(data = train_components, columns = ['PCA_1', 'PCA_2',
                                                    'PCA_3', 'PCA_4', 'PCA_5'] )
pca_train_df['Cluster'] = df_training.iloc[:,-1]
pca_train_df.head()
# Out:
#       PCA_1     PCA_2     PCA_3     PCA_4     PCA_5  Cluster
# 0 -5.520280 -0.290278 -1.529930  1.333454  1.425370        2
# 1 -5.535350 -0.082530 -1.924804  0.671267  0.671233        2
# 2 -5.474988  0.287387 -2.144642  0.531787  0.207799        2
# 3 -5.677232  0.897031 -2.018220  0.157141  0.759119        2
# 4 -5.748749  1.162952 -2.139533  0.207820  0.473116        2

# %%
#Now for the test set
pca_test_df = pd.DataFrame(data = test_components, columns = ['PCA_1', 'PCA_2',
                                                    'PCA_3', 'PCA_4', 'PCA_5'] )
pca_test_df.head()
# Out:
#       PCA_1     PCA_2     PCA_3     PCA_4     PCA_5
# 0 -2.754984 -1.387994  0.129405 -0.182217 -0.421156
# 1 -4.399115 -1.256752 -0.480584  0.001501 -0.187865
# 2 -5.066335 -0.616208 -1.428891 -0.067983  0.384310
# 3 -5.186594 -0.900992 -1.470125  0.322356  0.968111
# 4 -5.080981 -1.593048 -1.103905  0.179656  0.846864

# %%
#Returns the variance explained by each principal component 
print(pca.explained_variance_ratio_)
# Out:
# [0.61641815 0.04906494 0.03419337 0.01852617 0.01601355]

# %%
#Scree plot to visualize variance explained by each component
scree_plot =  pd.DataFrame({'var':pca.explained_variance_ratio_,
             'PC':['PC_1','PC_2','PC_3','PC_4','PC_5']})
sns.barplot(x='PC',y="var", 
           data=scree_plot, color="c")
# Out:
# <AxesSubplot:xlabel='PC', ylabel='var'>

# %%
sns.lmplot( x="PCA_1", y ='PCA_2',
  data=pca_train_df, 
  fit_reg=False,  # color by cluster
  legend=True,
  hue = 'Cluster',
  scatter_kws={"s": 80}) # specify the point size

# %%
pca_real = PCA(n_components = 1)

# %%
#Now we have to extract only the independent variables 
x_train_pca = df_training.iloc[:,:-2]
x_test_pca = df_testing.iloc[:,:-2]

# %%
#Now let's fit our features to our pca model on both training and test sets
train_components = pca_real.fit_transform(x_train_pca)
test_components = pca_real.fit_transform(x_test_pca)

# %%
#Let's look at our pca features for training set 
pca_train_df = pd.DataFrame(data = train_components, columns = ['PCA_1'] )
pca_train_df.head()
# Out:
#       PCA_1
# 0 -5.520280
# 1 -5.535350
# 2 -5.474988
# 3 -5.677232
# 4 -5.748749

# %%
#Now for the test set
pca_test_df = pd.DataFrame(data = test_components, columns = ['PCA_1'] )
pca_test_df.head()
# Out:
#       PCA_1
# 0 -2.754984
# 1 -4.399115
# 2 -5.066335
# 3 -5.186594
# 4 -5.080981

# %%
#Before using these features to train our model, we should turn our categorical 'activity' variable to numerical 
df_training['Activity'] = np.where((df_training['Activity'] == 'LAYING') , 1, df_training['Activity'])
df_training['Activity'] = np.where((df_training['Activity'] == 'STANDING') , 2, df_training['Activity'])
df_training['Activity'] = np.where((df_training['Activity'] == 'SITTING') , 3, df_training['Activity'])
df_training['Activity'] = np.where((df_training['Activity'] == 'WALKING') , 4, df_training['Activity'])
df_training['Activity'] = np.where((df_training['Activity'] == 'WALKING_UPSTAIRS') , 5, df_training['Activity'])
df_training['Activity'] = np.where((df_training['Activity'] == 'WALKING_DOWNSTAIRS') , 6, df_training['Activity'])
# Out:
# C:\Users\alexa\Anaconda3\lib\site-packages\pandas\core\ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
#Now if we look at our acitivity column we have changed values to numbers
df_training['Activity'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Activity, dtype: int64

# %%
#Now let's do the same for testing
df_testing['Activity'] = np.where((df_testing['Activity'] == 'LAYING') , 1, df_testing['Activity'])
df_testing['Activity'] = np.where((df_testing['Activity'] == 'STANDING') , 2, df_testing['Activity'])
df_testing['Activity'] = np.where((df_testing['Activity'] == 'SITTING') , 3, df_testing['Activity'])
df_testing['Activity'] = np.where((df_testing['Activity'] == 'WALKING') , 4, df_testing['Activity'])
df_testing['Activity'] = np.where((df_testing['Activity'] == 'WALKING_UPSTAIRS') , 5, df_testing['Activity'])
df_testing['Activity'] = np.where((df_testing['Activity'] == 'WALKING_DOWNSTAIRS') , 6, df_testing['Activity'])

# %%
df_testing['Activity'].head()
# Out:
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# Name: Activity, dtype: int64

# %%
df_training['Activity'] = pd.to_numeric(df_training['Activity'])
df_testing['Activity'] = pd.to_numeric(df_testing['Activity'])

# %%
#Now let's get our x and y features
x_train = pca_train_df.iloc[:,:]
y_train = df_training.iloc[:,-1]

x_test = pca_test_df.iloc[:,:]
y_test = df_testing.iloc[:,-1]

# %%
#initializing our lists so we can later store the best params that achieve best scores across metrics
accuracy_best_params = []
roc_auc_best_params = []
f1_best_params = []


#Now that we have our new features, we can use them to train our KNN model
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold

#Making a grid of values we want our grid search to test to find the best parameters
grid_values ={'n_neighbors': list(range(1,105,4))}

knn = KNeighborsClassifier()

knn_classifier = GridSearchCV(estimator = knn, param_grid = grid_values, cv = StratifiedKFold(n_splits = 5),
                      scoring = ['accuracy', 'roc_auc_ovr', 'f1_micro'], refit = False, verbose = 0)

knn_model = knn_classifier.fit(x_train, y_train)


accuracy_best_params.append(knn_model.cv_results_['params'][ np.argmin(knn_model.cv_results_['rank_test_accuracy'])])
roc_auc_best_params.append(knn_model.cv_results_['params'][ np.argmin(knn_model.cv_results_['rank_test_roc_auc_ovr'])])
f1_best_params.append(knn_model.cv_results_['params'][ np.argmin(knn_model.cv_results_['rank_test_f1_micro']) ])

# %%
accuracy_best_params
# Out:
# [{'n_neighbors': 61}]

# %%
roc_auc_best_params
# Out:
# [{'n_neighbors': 101}]

# %%
f1_best_params
# Out:
# [{'n_neighbors': 61}]

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
accuracy_test_score = []

knn_clf = KNeighborsClassifier(n_neighbors = 17)
model = knn_clf.fit(x_train, y_train)

y_pred = model.predict(x_test)

accuracy_test_score.append(accuracy_score(y_test, y_pred))

# %%
accuracy_test_score
# Out:
# [0.4462164913471327]
